# %% [raw]
# import pandas as  pd
# import requests

# %%
response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=a5eaa3d940661eb373881a9812019034&page=2')

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/7FTOVQO3pndOuswVS3iNt3odVq5.jpg',
#   'genre_ids': [27],
#   'id': 691363,
#   'original_language': 'fr',
#   'original_title': 'La Chose Derrière La Porte',
#   'overview': 'The story of Adèle, a youg woman who’s literally haunted by the death of her husband, killed in a trench during World War One. Desperate and unable to face this tragic loss, Adèle turns to black magic in the hope to bring her lover back. The miracle will happen, but Adèle will have to pay the price for opening this Pandora Box.',
#   'popularity': 113.5041,
#   'poster_path': '/iFqHmF8ZSY9jOhstqeRxuzxPkFp.jpg',
#   'release_date': '2023-01-16',
#   'title': 'The Thing Behind The Door',
#   'video': False,
#   'vote_average': 5.524,
#   'vote_count': 22},
#  {'adult': False,
#   'backdrop_path': '/zfaZ8m6NHzylqTumf94mDGtQwKM.jpg',
#   'genre_ids': [36, 18],
#   'id': 1265344,
#   'original_language': 'en',
#   'original_title': 'Swiped',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /j7MKdRIwfJejNlJQG1hzjFJmtlH.jpg         [16, 28, 14, 53]  1311031
# 1   False  /iZLqwEwUViJdSkGVjePGhxYzbDb.jpg                [878, 53]   755898
# 2   False  /9KSboWOt09J72aMY4x8SS1IaOHK.jpg             [16, 28, 12]   987400
# 3   False  /mEW9XMgYDO6U0MJcIRqRuSwjzN5.jpg                 [28, 53]  1007734
# 4   False  /fq8gLtrz1ByW3KQ2IM3RMZEIjsQ.jpg                     [27]  1038392
# 5   False  /or8y8JFF0vR3N9ap0Vdhf9tfTxQ.jpg                 [28, 80]  1028248
# 6   False  /wJ20rOZ1VgkCqv1jeOQB2Brny9k.jpg               [27, 9648]  1078605
# 7   False  /eU7IfdWq8KQy0oNd4kKXS0QUR08.jpg            [878, 12, 28]  1061474
# 8   False  /mwI1OarF7BVWwn5O1Ng73UhyctP.jpg            [27, 878, 53]   914215
# 9   False   /kzeBfhXMRWiykBsqoL3UbfaM0S.jpg             [35, 28, 80]  1035259
# 10  False  /xSD0q1FiuZkvHuy7uscOLbmd1hR.jpg             [12, 28, 14]    13494
# ...

# %%
df=pd.DataFrame(response.json()['results'])[['id','title','popularity','release_date','vote_count','vote_average']]

# %%
df.head()
# Out:
#         id                                           title  popularity  \
# 0  1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle    668.2088
# 1   755898                               War of the Worlds    486.9785
# 2   987400                  Aztec Batman: Clash of Empires    323.2756
# 3  1007734                                        Nobody 2    269.0949
# 4  1038392                       The Conjuring: Last Rites    288.9608
#
#   release_date  vote_count  vote_average
# 0   2025-07-18         327         7.800
# 1   2025-07-29         568         4.371
# 2   2025-09-18          46         8.043
# 3   2025-08-13         629         7.200
# 4   2025-09-03         403         6.600

# %%
df=pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,100):
    response=requests.get('https://api.themoviedb.org/3/movie/popular?api_key=a5eaa3d940661eb373881a9812019034&page={}'.format(i))
    temp_df=pd.DataFrame(response.json()['results'])[['id','title','popularity','release_date','vote_count','vote_average']]
    df=pd.concat([df,temp_df],ignore_index=True)

# %%
print("HI")
# Out:
# HI

# %%
df
# Out:
#            id                                           title  popularity  \
# 0     1311031  Demon Slayer: Kimetsu no Yaiba Infinity Castle    668.2088
# 1      755898                               War of the Worlds    486.9785
# 2      987400                  Aztec Batman: Clash of Empires    323.2756
# 3     1007734                                        Nobody 2    269.0949
# 4     1038392                       The Conjuring: Last Rites    288.9608
# ...       ...                                             ...         ...
# 1975      534                            Terminator Salvation      7.3649
# 1976   449443                                  Den of Thieves      8.6407
# 1977   981588                      The No Man Zone. The Movie      6.9384
# 1978   437342                                  The First Omen      7.6861
# 1979   522402                                           Finch      7.9445
#
#      release_date  vote_count  vote_average
# ...

# %%
df.to_csv('movies.csv')
